# %% [markdown]
# # 1

# %%
import pandas as pd 
df=pd.read_csv('titanic1')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    male  28.0      0      0
# 1             1           76         0       3    male  25.0      0      0
# 2             2          641         0       3    male  20.0      0      0
# 3             3          568         0       3  female  29.0      0      4
# 4             4          672         0       1    male  31.0      1      0
# ..          ...          ...       ...     ...     ...   ...    ...    ...
# 707         885          150         0       2    male  42.0      0      0
# 708         886           10         1       2  female  14.0      1      0
# 709         887           61         0       3    male  22.0      0      0
# 710         888          535         0       3  female  30.0      0      0
# 711         890          428         1       2  female  19.0      0      0
#
#         Fare Embarked    Title  FamilySize
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Sex']=encoder.fit_transform(df['Sex'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare Embarked    Title  FamilySize
# 0    13.0000        S      Mrs           1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Embarked']=encoder.fit_transform(df['Embarked'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare  Embarked    Title  FamilySize
# 0    13.0000         2      Mrs           1
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Title']=encoder.fit_transform(df['Title'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare  Embarked  Title  FamilySize
# 0    13.0000         2      2           1
# ...

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

x=df[["Pclass", "Sex", "Age", "Embarked","SibSp","Parch","Fare","Title","FamilySize"]]
y=df["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
Dtree = tree.DecisionTreeClassifier()  
Dtree.fit(x_train, y_train)   #fitting our model
y_pred=Dtree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7972027972027972

# %% [markdown]
# # 2

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(30,20))
plot_tree(Dtree,filled=tree,feature_names=x.columns,proportion=True)
# Out:
# [Text(545.902734375, 1061.3142857142857, 'Sex <= 0.5\ngini = 0.484\nsamples = 100.0%\nvalue = [0.591, 0.409]'),
#  Text(297.309375, 1009.5428571428572, 'Pclass <= 2.5\ngini = 0.376\nsamples = 36.4%\nvalue = [0.251, 0.749]'),
#  Text(179.60625, 957.7714285714286, 'Fare <= 28.856\ngini = 0.091\nsamples = 22.1%\nvalue = [0.048, 0.952]'),
#  Text(149.9625, 906.0, 'Fare <= 28.231\ngini = 0.16\nsamples = 10.0%\nvalue = [0.088, 0.912]'),
#  Text(136.0125, 854.2285714285715, 'Age <= 56.0\ngini = 0.133\nsamples = 9.8%\nvalue = [0.071, 0.929]'),
#  Text(90.675, 802.4571428571429, 'SibSp <= 0.5\ngini = 0.105\nsamples = 9.5%\nvalue = [0.056, 0.944]'),
#  Text(41.849999999999994, 750.6857142857143, 'Age <= 24.5\ngini = 0.054\nsamples = 6.3%\nvalue = [0.028, 0.972]'),
#  Text(27.9, 698.9142857142858, 'Age <= 23.5\ngini = 0.153\nsamples = 2.1%\nvalue = [0.083, 0.917]'),
#  Text(13.95, 647.1428571428571, 'gini = 0.0\nsamples = 1.6%\nvalue = [0.0, 1.0]'),
# ...

# %%
Dtree = tree.DecisionTreeClassifier(max_depth=3)  
Dtree.fit(x_train, y_train)   #fitting our model
y_pred=Dtree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8321678321678322

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize=(30,20))
plot_tree(Dtree,filled=tree,feature_names=x.columns,proportion=True)
# Out:
# [Text(837.0, 951.3000000000001, 'Sex <= 0.5\ngini = 0.484\nsamples = 100.0%\nvalue = [0.591, 0.409]'),
#  Text(418.5, 679.5, 'Pclass <= 2.5\ngini = 0.376\nsamples = 36.4%\nvalue = [0.251, 0.749]'),
#  Text(209.25, 407.70000000000005, 'Fare <= 28.856\ngini = 0.091\nsamples = 22.1%\nvalue = [0.048, 0.952]'),
#  Text(104.625, 135.89999999999998, 'gini = 0.16\nsamples = 10.0%\nvalue = [0.088, 0.912]'),
#  Text(313.875, 135.89999999999998, 'gini = 0.029\nsamples = 12.1%\nvalue = [0.014, 0.986]'),
#  Text(627.75, 407.70000000000005, 'Fare <= 20.8\ngini = 0.491\nsamples = 14.2%\nvalue = [0.568, 0.432]'),
#  Text(523.125, 135.89999999999998, 'gini = 0.498\nsamples = 10.5%\nvalue = [0.467, 0.533]'),
#  Text(732.375, 135.89999999999998, 'gini = 0.245\nsamples = 3.7%\nvalue = [0.857, 0.143]'),
#  Text(1255.5, 679.5, 'Age <= 7.0\ngini = 0.338\nsamples = 63.6%\nvalue = [0.785, 0.215]'),
#  Text(1046.25, 407.70000000000005, 'FamilySize <= 5.0\ngini = 0.42\nsamples = 3.5%\nvalue = [0.3, 0.7]'),
# ...

# %% [markdown]
# in this decision tree , first , if sex <= 0.5 , then it checks the age , if age is <= 7.0 then it checks pclass , if pclass<=1.5 ....

# %% [markdown]
# # 3

# %%
Dtree = tree.DecisionTreeClassifier(splitter='random',min_samples_leaf=6,max_depth=5)  
Dtree.fit(x_train, y_train)   #fitting our model
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=6, splitter='random')

# %% [markdown]
# # 4

# %%
y_pred=Dtree.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.8111888111888111

# %% [markdown]
# # 5

# %%
clf=RandomForestClassifier(n_estimators=10)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8321678321678322

# %% [markdown]
# # 6

# %%
clf=RandomForestClassifier(n_estimators=100)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8181818181818182

# %% [markdown]
# the accuracy with estimators =100 is less then the accuracy with estimators=10
