# %% [markdown]
# # 1
# ## importation

# %%
import pandas as pd 
df=pd.read_csv('titanic1')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    male  28.0      0      0
# 1             1           76         0       3    male  25.0      0      0
# 2             2          641         0       3    male  20.0      0      0
# 3             3          568         0       3  female  29.0      0      4
# 4             4          672         0       1    male  31.0      1      0
# ..          ...          ...       ...     ...     ...   ...    ...    ...
# 707         885          150         0       2    male  42.0      0      0
# 708         886           10         1       2  female  14.0      1      0
# 709         887           61         0       3    male  22.0      0      0
# 710         888          535         0       3  female  30.0      0      0
# 711         890          428         1       2  female  19.0      0      0
#
#         Fare Embarked    Title  FamilySize
# ...

# %% [markdown]
# ## visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(df.Title,df.Survived)
plt.title("title vs survived")
# Out:
# Text(0.5, 1.0, 'title vs survived')

# %%
plt.scatter(df.FamilySize,df.Survived)
plt.title("family size vs survived")
# Out:
# Text(0.5, 1.0, 'family size vs survived')

# %%
plt.scatter(df.Age,df.Survived)
plt.title("Age vs survived")
# Out:
# Text(0.5, 1.0, 'Age vs survived')

# %%
plt.scatter(df.Sex,df.Survived)
plt.title("sex vs survived")
# Out:
# Text(0.5, 1.0, 'sex vs survived')

# %% [markdown]
# ## logistic regression

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x=df[["Age", "Pclass"]]
y=df["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) #splitting data with test size of 20%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.68

# %%
x=df[["Age", "Pclass","FamilySize"]]
y=df["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) #splitting data with test size of 20%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.69

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Sex']=encoder.fit_transform(df['Sex'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare Embarked    Title  FamilySize
# 0    13.0000        S      Mrs           1
# ...

# %%
df['Embarked']=encoder.fit_transform(df['Embarked'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare  Embarked    Title  FamilySize
# 0    13.0000         2      Mrs           1
# ...

# %%
df['Title']=encoder.fit_transform(df['Title'])
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch  \
# 0             0          343         0       2    1  28.0      0      0
# 1             1           76         0       3    1  25.0      0      0
# 2             2          641         0       3    1  20.0      0      0
# 3             3          568         0       3    0  29.0      0      4
# 4             4          672         0       1    1  31.0      1      0
# ..          ...          ...       ...     ...  ...   ...    ...    ...
# 707         885          150         0       2    1  42.0      0      0
# 708         886           10         1       2    0  14.0      1      0
# 709         887           61         0       3    1  22.0      0      0
# 710         888          535         0       3    0  30.0      0      0
# 711         890          428         1       2    0  19.0      0      0
#
#         Fare  Embarked  Title  FamilySize
# 0    13.0000         2      2           1
# ...

# %%
x=df[["Age", "Pclass","FamilySize","Sex","Embarked","Title"]]
y=df["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) #splitting data with test size of 20%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.82

# %%
x=df[["Age", "Pclass","FamilySize","Sex","Embarked","Title","Fare"]]
y=df["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) #splitting data with test size of 20%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.83

# %% [markdown]
# # 2

# %%
confusion_matrix=pd.crosstab(y_test,y_pred,rownames=['Actual'], colnames=['Predited'])
print(confusion_matrix)
# Out:
# Predited   0   1
# Actual
# 0         71   4
# 1         21  47

# %% [markdown]
# this confusion matrix shows that the false positifs and the false negatifs are less than the true postifs and the true negatifs
# so our logistic regression is performant

# %% [markdown]
# # 3

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
    
x=df[["Age", "Pclass","FamilySize","Sex","Embarked","Title","Fare"]]
y=df["Survived"]

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) 

clf_tree = DecisionTreeClassifier(); 
clf_reg = LogisticRegression();
clf_tree.fit(x_train, y_train); 
clf_reg.fit(x_train, y_train); 

y_score1 = clf_tree.predict_proba(x_test)[:,1]
y_score2 = clf_reg.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
false_positive_rate2, true_positive_rate2, threshold2 = roc_curve(y_test, y_score2)

print('roc_auc_score for DecisionTree: ', roc_auc_score(y_test, y_score1))
print('roc_auc_score for Logistic Regression: ', roc_auc_score(y_test, y_score2))

plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - DecisionTree')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
plt.subplots(1, figsize=(10,10))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate2, true_positive_rate2)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# roc_auc_score for DecisionTree:  0.8133333333333334
# roc_auc_score for Logistic Regression:  0.9083333333333333

# %% [markdown]
# Une courbe ROC (receiver operating characteristic) est un graphique représentant les performances d'un modèle de classification pour tous les seuils de classification. Cette courbe trace le taux de vrais positifs en fonction du taux de faux positifs
# AUC signifie "aire sous la courbe ROC". Cette valeur mesure l'intégralité de l'aire à deux dimensions située sous l'ensemble de la courbe ROC (par calculs d'intégrales) de (0,0) à (1,1)
