# %% [markdown]
# # preprocessing part

# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv', sep=";")
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
df=pd.read_csv('titanic-passengers.csv', sep=";")
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].fillna(df['Age'].mode(), inplace=True)

# %%
df['Age'].mode()[0]
# Out:
# 24.0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 885          150       No       2
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # VISUALISATION PART

# %% [markdown]
# ## 1

# %%
import matplotlib.pyplot as plt
plt.xlabel("Survived or not")
plt.ylabel("how many")
plt.title("survived")
vc=df['Survived'].value_counts()
vc.plot.bar(rot=45)

# %%
import matplotlib.pyplot as plt
plt.xlabel("male or female")
plt.ylabel("how many")
plt.title("sex")
vc=df['Sex'].value_counts()
vc.plot.bar(rot=45)

# %%
plt.title("Histogram of age")
plt.xlabel("Age")
df['Age'].plot.hist()

# %%
plt.title("Histogram of Pclass")
plt.xlabel("Pclass")
df['Pclass'].plot.hist()

# %% [markdown]
# ## 2

# %%
import seaborn as sns
grid=sns.FacetGrid(df, row='Survived',col='Sex',size=2.0 , aspect=1.6)
grid.map(plt.hist, 'Age', color="purple")
grid.add_legend()
# Out:
# C:\Users\Yasmine Regaieg\anaconda3\Nouveau dossier\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## 3

# %%
grid=sns.FacetGrid(df, row='Survived',col='Pclass',size=2.0 , aspect=1.6)
grid.map(plt.hist, 'Embarked', color="purple")
grid.add_legend()

# %% [markdown]
# ## 4

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(df)

# %% [raw]
# this function describes the correlations between all of the features in our data set at the same time

# %% [markdown]
# ## 5

# %%
df[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-179-8fe0cfbe9ff1> in <module>
# ----> 1 df[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, *args, **kwargs)
#    1223         """
#    1224         nv.validate_groupby_func("mean", args, kwargs, ["numeric_only"])
# -> 1225         return self._cython_agg_general(
#    1226             "mean", alt=lambda x, axis: Series(x).mean(**kwargs), **kwargs
#    1227         )
#
# ~\anaconda3\Nouveau dossier\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     991         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#     992     ) -> DataFrame:
# --> 993         agg_blocks, agg_items = self._cython_agg_blocks(
# ...

# %%
cleanup_nums={
    "Survived":{"No":0, "Yes":1}
}
df.replace(cleanup_nums, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 885          150         0       2
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.652174
# 2       0.479769
# 3       0.239437

# %% [markdown]
# ## 6

# %%
df.drop("Ticket",axis=1, inplace=True)
df['Title'] = df.Name.apply(lambda name: name.split(',')[1].split('.')[0].strip())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 885          150         0       2
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop("Name",axis=1, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            343         0       2    male  28.0      0      0  13.0000
# 1             76         0       3    male  25.0      0      0   7.6500
# 2            641         0       3    male  20.0      0      0   7.8542
# 3            568         0       3  female  29.0      0      4  21.0750
# 4            672         0       1    male  31.0      1      0  52.0000
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 885          150         0       2    male  42.0      0      0  13.0000
# 886           10         1       2  female  14.0      1      0  30.0708
# 887           61         0       3    male  22.0      0      0   7.2292
# 888          535         0       3  female  30.0      0      0   8.6625
# 890          428         1       2  female  19.0      0      0  26.0000
#
#     Embarked Title
# 0          S    Mr
# 1          S    Mr
# 2          S    Mr
# 3          S   Mrs
# ...

# %% [markdown]
# ## 7

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Age',bins=20)

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Fare',bins=20)

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Sex',bins=20)

# %% [markdown]
# ## 8

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty" ,

                  "the Countess": "Royalty",

                    "Dona":       "Royalty" ,

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs" ,

                    "Master" :    "Master" ,

                    }
df.Title = df.Title.map(Title_Dictionary)
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            343         0       2    male  28.0      0      0  13.0000
# 1             76         0       3    male  25.0      0      0   7.6500
# 2            641         0       3    male  20.0      0      0   7.8542
# 3            568         0       3  female  29.0      0      4  21.0750
# 4            672         0       1    male  31.0      1      0  52.0000
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 885          150         0       2    male  42.0      0      0  13.0000
# 886           10         1       2  female  14.0      1      0  30.0708
# 887           61         0       3    male  22.0      0      0   7.2292
# 888          535         0       3  female  30.0      0      0   8.6625
# 890          428         1       2  female  19.0      0      0  26.0000
#
#     Embarked    Title
# 0          S      Mrs
# 1          S      Mrs
# 2          S      Mrs
# ...

# %% [markdown]
# ## 9

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Age',bins=20)

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Fare',bins=20)

# %%
g=sns.FacetGrid(df,col='Title')
g.map(plt.hist,'Sex',bins=20)

# %% [markdown]
#  ## 10

# %%
df['FamilySize'] = df.Parch + df.SibSp + 1
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            343         0       2    male  28.0      0      0  13.0000
# 1             76         0       3    male  25.0      0      0   7.6500
# 2            641         0       3    male  20.0      0      0   7.8542
# 3            568         0       3  female  29.0      0      4  21.0750
# 4            672         0       1    male  31.0      1      0  52.0000
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 885          150         0       2    male  42.0      0      0  13.0000
# 886           10         1       2  female  14.0      1      0  30.0708
# 887           61         0       3    male  22.0      0      0   7.2292
# 888          535         0       3  female  30.0      0      0   8.6625
# 890          428         1       2  female  19.0      0      0  26.0000
#
#     Embarked    Title  FamilySize
# 0          S      Mrs           1
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age     Fare Embarked    Title  \
# 0            343         0       2    male  28.0  13.0000        S      Mrs
# 1             76         0       3    male  25.0   7.6500        S      Mrs
# 2            641         0       3    male  20.0   7.8542        S      Mrs
# 3            568         0       3  female  29.0  21.0750        S      Mrs
# 4            672         0       1    male  31.0  52.0000        S      Mrs
# ..           ...       ...     ...     ...   ...      ...      ...      ...
# 885          150         0       2    male  42.0  13.0000        S  Officer
# 886           10         1       2  female  14.0  30.0708        C      Mrs
# 887           61         0       3    male  22.0   7.2292        C      Mrs
# 888          535         0       3  female  30.0   8.6625        S     Miss
# 890          428         1       2  female  19.0  26.0000        S     Miss
#
#      FamilySize
# 0             1
# 1             1
# ...

# %% [markdown]
# ## 11

# %%
g=sns.FacetGrid(df,col='Survived')
g.map(plt.hist,'FamilySize',bins=20)

# %% [raw]
# this feature shows how many persons are in the same family but the graph above shows that the family's size does no have an impact on will the family survive or not , so this feature is not that important.
